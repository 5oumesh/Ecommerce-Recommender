# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load processed tables
users = pd.read_csv("../data/processed/users.csv")
products = pd.read_csv("../data/processed/products.csv")
interactions = pd.read_csv("../data/processed/interactions.csv")

print("Users:", users.shape)
print("Products:", products.shape)
print("Interactions:", interactions.shape)
# Out:
# Users: (10486, 1)
# Products: (4692, 2)
# Interactions: (39478, 5)

# %%
event_counts = interactions["event_type"].value_counts()

print(event_counts)

event_counts.plot(kind="bar", title="Event Type Distribution")
plt.xlabel("Event Type")
plt.ylabel("Count")
plt.show()
# Out:
# event_type
# view        37642
# cart          969
# purchase      867
# Name: count, dtype: int64

# %%
user_activity = interactions.groupby("user_id").size()

print(user_activity.describe())

user_activity.hist(bins=30)
plt.title("User Activity Distribution")
plt.xlabel("Interactions per User")
plt.ylabel("Number of Users")
plt.show()
# Out:
# count    10486.000000
# mean         3.764829
# std          2.485477
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         48.000000
# dtype: float64

# %%
product_popularity = interactions.groupby("product_id").size()

print(product_popularity.describe())

product_popularity.hist(bins=30)
plt.title("Product Popularity Distribution")
plt.xlabel("Interactions per Product")
plt.ylabel("Number of Products")
plt.show()
# Out:
# count    4692.000000
# mean        8.413896
# std        17.844136
# min         3.000000
# 25%         3.000000
# 50%         4.000000
# 75%         8.000000
# max       521.000000
# dtype: float64

# %%
top_categories = products["category_code"].value_counts().head(10)

print(top_categories)

top_categories.plot(kind="bar", title="Top 10 Product Categories")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()
# Out:
# category_code
# unknown                             1744
# electronics.smartphone               492
# computers.notebook                   168
# electronics.clocks                   162
# appliances.kitchen.refrigerators     122
# appliances.environment.vacuum        118
# apparel.shoes                        107
# electronics.video.tv                 100
# appliances.kitchen.washer             89
# auto.accessories.player               82
# Name: count, dtype: int64
